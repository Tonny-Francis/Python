# %%
#Importação das Bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from  sklearn.model_selection  import  train_test_split 
from  sklearn.tree  import  export_graphviz 
from  sklearn  import  tree
from  sklearn  import  metrics
# %matplotlib inline

# %%
#Importando as bases de dados
#Dataframe de treinamento
df_treino = pd.read_csv('train.csv')

#Dataframe de teste
df_teste = pd.read_csv('test.csv')

# %%
#Vendo as 5 primeiras linhas do df_treino
df_treino.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
#Estatísticas
df_treino.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# std        8.474601     19.245033      8.164537     49.960477    151.039033
# min        0.760000      0.000000      0.000000      0.000000      0.000000
# 25%       16.665000     47.000000      7.001500      4.000000     36.000000
# 50%       24.240000     62.000000     12.998000     17.000000    118.000000
# 75%       31.060000     77.000000     16.997900     49.000000    222.000000
# max       45.455000    100.000000     56.996900    367.000000    886.000000
#
#               count
# count  10886.000000
# mean     191.574132
# std      181.144454
# min        1.000000
# 25%       42.000000
# 50%      145.000000
# 75%      284.000000
# max      977.000000

# %%
#Verificando valores nulos
df_treino.isnull().sum()
# Out:
# datetime      0
# season        0
# holiday       0
# workingday    0
# weather       0
# temp          0
# atemp         0
# humidity      0
# windspeed     0
# casual        0
# registered    0
# count         0
# dtype: int64

# %%
#Adicionando uma nova coluna e renomeando 
df_treino.insert(1, 'day', '')
df_treino.insert(2, 'hours', '')

df_treino = df_treino.rename(columns = {'datetime': 'date'})
df_treino.head()
# Out:
#                   date day hours  season  holiday  workingday  weather  temp  \
# 0  2011-01-01 00:00:00                 1        0           0        1  9.84
# 1  2011-01-01 01:00:00                 1        0           0        1  9.02
# 2  2011-01-01 02:00:00                 1        0           0        1  9.02
# 3  2011-01-01 03:00:00                 1        0           0        1  9.84
# 4  2011-01-01 04:00:00                 1        0           0        1  9.84
#
#     atemp  humidity  windspeed  casual  registered  count
# 0  14.395        81        0.0       3          13     16
# 1  13.635        80        0.0       8          32     40
# 2  13.635        80        0.0       5          27     32
# 3  14.395        75        0.0       3          10     13
# 4  14.395        75        0.0       0           1      1

# %%
#Separando data de hora
aux_0 = df_treino['date'].unique()
day = 1

for x in range(len(df_treino)):
    #Extraindo data
    aux_1 = aux_0[x-1]
    date = aux_1[0:10]

    df_treino.at[x, 'date'] = date

    #Extraindo hora
    aux_1 = aux_0[x]
    hours = aux_1[10:13]

# 42  2011-01-02   3    19       1        0           0        1  13.12  14.395
# 43  2011-01-02   3    20       1        0           0        1  12.30  13.635
# 44  2011-01-02   3    21       1        0           0        1  10.66  11.365
# 45  2011-01-02   3    22       1        0           0        1   9.84  10.605
# 46  2011-01-02   3    23       1        0           0        1   9.02  11.365
# 47  2011-01-02   3    00       1        0           1        1   9.02   9.850
# 48  2011-01-03   4    01       1        0           1        1   8.20   8.335
# 49  2011-01-03   4    04       1        0           1        1   6.56   6.820
#
#     humidity  windspeed  casual  registered  count
# 0         81     0.0000       3          13     16
# 1         80     0.0000       8          32     40
# 2         80     0.0000       5          27     32
# 3         75     0.0000       3          10     13
# 4         75     0.0000       0           1      1
# 5         75     6.0032       0           1      1
# 6         80     0.0000       2           0      2
# 7         86     0.0000       1           2      3
# 8         75     0.0000       1           7      8
# 9         76     0.0000       8           6     14
# 10        76    16.9979      12          24     36
# 11        81    19.0012      26          30     56
# 12        77    19.0012      29          55     84
# 13        72    19.9995      47          47     94
# 14        72    19.0012      35          71    106
# 15        77    19.9995      40          70    110
# 16        82    19.9995      41          52     93
# 17        82    19.0012      15          52     67
# 18        88    16.9979       9          26     35
# 19        88    16.9979       6          31     37
# 20        87    16.9979      11          25     36
# 21        87    12.9980       3          31     34
# 22        94    15.0013      11          17     28
# 23        88    19.9995      15          24     39
# 24        88    19.9995       4          13     17
# 25        94    16.9979       1          16     17
# 26       100    19.0012       1           8      9
# 27        94    12.9980       2           4      6
# 28        94    12.9980       2           1      3
# 29        77    19.9995       0           2      2
# 30        76    12.9980       0           1      1
# 31        71    15.0013       0           8      8
# 32        76    15.0013       1          19     20
# 33        81    15.0013       7          46     53
# 34        71    16.9979      16          54     70
# 35        66    19.9995      20          73     93
# 36        66     8.9981      11          64     75
# 37        76    12.9980       4          55     59
# 38        81    11.0014      19          55     74
# 39        71    11.0014       9          67     76
# 40        57    12.9980       7          58     65
# 41        46    22.0028      10          43     53
# 42        42    30.0026       1          29     30
# 43        39    23.9994       5          17     22
# 44        44    22.0028      11          20     31
# 45        44    19.9995       0           9      9
# 46        47    11.0014       0           8      8
# 47        44    23.9994       0           5      5
# 48        44    27.9993       0           2      2
# 49        47    26.0027       0           1      1

# %%
#Separando o target
y_test = df_treino['count']
y_test.head()
# Out:
# 0    16
# 1    40
# 2    32
# 3    13
# 4     1
# Name: count, dtype: int64

# %%
x_graph_1 = []
y_graph_1 = []

for x in range(7):
    x_graph_1.append(x+1)

    aux_0 = df_treino.query('day == {}'.format(x+1))
    y_graph_1.append(aux_0['count'].sum())

plt.bar(x_graph_1, y_graph_1, width=0.5, edgecolor="white", linewidth=0.7)
# Out:
# <BarContainer object of 7 artists>

# %%
#Removendo colunas não utilizadas, montando as features
df_treino = df_treino.drop(columns= ['date', 'casual', 'registered', 'count'])
